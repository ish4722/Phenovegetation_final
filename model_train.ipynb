# %%
# !pip install tensorflow==2.8.4 keras==2.8.0 efficientnet==1.1.1 segmentation-models
# Out:
# Requirement already satisfied: tensorflow==2.8.4 in /usr/local/lib/python3.10/dist-packages (2.8.4)
# Requirement already satisfied: keras==2.8.0 in /usr/local/lib/python3.10/dist-packages (2.8.0)
# Requirement already satisfied: efficientnet==1.1.1 in /usr/local/lib/python3.10/dist-packages (1.1.1)
# Requirement already satisfied: segmentation-models in /usr/local/lib/python3.10/dist-packages (0.2.1)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (24.3.25)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (3.12.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (3.4.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (3.19.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (1.17.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (2.8.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.4) (1.68.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.1.1) (1.0.8)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.1.1) (0.24.0)
# Requirement already satisfied: image-classifiers==0.2.0 in /usr/local/lib/python3.10/dist-packages (from segmentation-models) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.8.4) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.4) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.4) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.4) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.4) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.4) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.4) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.4) (3.1.3)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.1.1) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.1.1) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.1.1) (11.0.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.1.1) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.1.1) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.1.1) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.1.1) (0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.4) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.4) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.4) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.4) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.4) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.4) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.4) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.4) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.4) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.4) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.4) (3.2.2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf

# %%
import os
import cv2

# %% [markdown]
# ## Convert Json label to image mask

# %%
import json
from skimage.draw import polygon
from skimage import io
import os
import glob
from tqdm import tqdm
import numpy as np

def fill_mask(blobs,mask,label):
    for l in blobs:
        fill_row_coords, fill_col_coords = polygon(l[1], l[0],l[2])
        mask[fill_row_coords, fill_col_coords] = label


def convert_annotation_json_to_mask(path_to_annotation_json, path_to_masks_folder,classes,label_value,pixel_value):

    f = open(path_to_annotation_json)
    train = []
    objects = json.load(f)
    annotations = objects['shapes']
    h = objects['imageHeight']
    w = objects['imageWidth']
    mask = np.zeros((h, w)).astype('uint8')
    for annot in annotations:
        label= annot['label']
        points = annot['points']

        x_coord = []
        y_coord = []
        l = []
        for p in points:
            x_coord.append(int(p[0]))
            y_coord.append(int(p[1]))
        shape = (h, w)
        l.append(np.array(x_coord))
        l.append(np.array(y_coord))
        l.append(shape)

        if not label_value.get(label):
            label_value[label]=pixel_value[0]
            pixel_value[0]+=100

        if not classes.get(label):
            classes[label]=[l]
        else:
            classes[label].append(l)

    for label in classes:
        fill_mask(classes[label], mask,label_value[label])
        classes[label]=[]

    io.imsave(path_to_masks_folder, mask)

def get_classes(dataset_path):
    classes=dict()
    count=0
    pixel_value=[100]
    label_value=dict()
    for dirpath, dirname, filename in os.walk(dataset_path):
        path_to_annotation_json=glob.glob(dirpath+"/*.json")
        for json_file in path_to_annotation_json:
            path_to_mask_png=json_file[0:-5]+"_mask.png"
            convert_annotation_json_to_mask(json_file, path_to_mask_png,classes,label_value,pixel_value)
            count+=1

    assert count, "Dataset folder path does not contain any json mask file"


    print(".png file of All json mask files saved in respective folders! ")
    labels=[1]*len(label_value)

    for label, value in label_value.items():
        labels[(value-100)//100]=label

    class_list=''
    for clss in labels:
        class_list += clss+"$"
    return class_list[0:-1]

# %%
classes = get_classes(r'/content/drive/MyDrive/test_vegetation_model')
print('classes names: ',classes.split('$'))
# Out:
# .png file of All json mask files saved in respective folders!
# classes names:  ['deciduous', 'coniferous']

# %% [markdown]
# ## Data preprocessing

# %%
import os
import glob
from tqdm import tqdm
import cv2
import numpy as np
import keras
import tensorflow as tf

class Dataset(tf.keras.utils.Sequence):
    def __init__(self, dataset_path, n_classes, augmentation=None):
        self.images_fps = []
        self.mask_fps = []
        self.n_classes = n_classes

        for dirpath, dirnames, filenames in os.walk(dataset_path):
            mask_src = glob.glob(dirpath + '/*.png')
            mask_src.sort()
            img_src = glob.glob(dirpath + '/*.JPG') + glob.glob(dirpath + '/*.jpeg')
            img_src.sort()

            if len(img_src):
                assert len(mask_src) != 0, f"{dirpath} does not contain any annotation mask file for the images."
                if len(mask_src) != 1:
                    assert len(mask_src) == len(img_src), (
                        f"{dirpath} contains {len(mask_src)} mask files but {len(img_src)} images."
                    )
                    self.mask_fps += mask_src
                else:
                    self.mask_fps += [mask_src[0]] * len(img_src)
                self.images_fps += img_src
            else:
                if len(mask_src):
                    print(f"Skipping {dirpath} as it contains masks but no images.")
                continue  # Skip directories with no images or masks

        assert len(self.images_fps) != 0, f"{dataset_path} does not contain any images."

        self.actaul_size = len(self.mask_fps)
        self.augmentation = augmentation


    def __getitem__(self, i):

        j=i
        if i>=self.actaul_size:
            j=i-self.actaul_size
        image = cv2.imread(self.images_fps[j])
        h,w,_=image.shape
        h=256
        w=256
        image = cv2.resize(image, (w, h))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        image = image.astype('float32') / 255.0  # Convert to float32 and normalize


        mask1 = cv2.imread(self.mask_fps[j],0)
        mask1 = cv2.resize(mask1, (w, h), interpolation=cv2.INTER_NEAREST)  # Resize without interpolation artifacts

        mask=[(mask1==((i+1)*100)) for i in range(self.n_classes)]

        mask = np.stack(mask, axis=-1)
        mask = mask.astype('float32')

        # add background to mask
        background = 1.0 * (mask1 == 0)
        deciduous = 1.0 * (mask1 == 100)
        coniferous = 1.0 * (mask1 == 200)

        mask = np.stack([background, deciduous, coniferous], axis=-1)
        mask=1.0*(mask>0.9)

        image = np.asarray(image, dtype=np.float32)
        mask = np.asarray(mask, dtype=np.float32)

        # apply augmentations
        if i>=self.actaul_size:
            sample = self.augmentation(image=image.astype('float32'), mask=mask.astype('float32'))
            image, mask = sample['image'], sample['mask']
            image = np.asarray(image, dtype=np.float32)
            mask = np.asarray(mask, dtype=np.float32)



        return (image, mask)

    def __len__(self):
        if self.augmentation:
            return self.actaul_size*2
        return self.actaul_size

# %% [markdown]
# Load data from dataset and form batches

# %%
import keras
class Dataloder(tf.keras.utils.Sequence):

    def __init__(self,indexes, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = indexes
        self.on_epoch_end()

    def __getitem__(self, i):

        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[self.indexes[j]])

        # transpose list of lists
        batch = tuple(np.stack(samples, axis=0) for samples in zip(*data))

        return batch

    def __len__(self):
        """batches per epoch"""
        return len(self.indexes) // self.batch_size

    def on_epoch_end(self):
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %% [markdown]
# ## Data Augmentation

# %%
# !pip uninstall imgaug
# !pip install imgaug==0.4.0
# !pip install albumentations

# %%
## Data Augmentation
import albumentations as A

def aug():
    train_transform = [

        # A.IAAAdditiveGaussianNoise(p=0.1),
        A.ShiftScaleRotate(scale_limit=0.1, rotate_limit=5, shift_limit=0.1, p=0.9, border_mode=0),
        A.HorizontalFlip(p=0.5),
        # A.IAAPerspective(p=0.5),

        A.OneOf(
            [
                # A.IAASharpen(p=1),
                A.Blur(blur_limit=3, p=1),
                A.MotionBlur(blur_limit=3, p=1),
            ],
            p=0.5,
        ),

        A.OneOf(
            [
                # A.RandomContrast(p=1),
                A.HueSaturationValue(p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.CLAHE(p=1),
                # A.RandomBrightness(p=1),
                A.RandomGamma(p=1),
            ],
            p=0.9,
        ),
    ]
    return A.Compose(train_transform)
# Out:
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 1.4.22 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %% [markdown]
# Function for visualising multiple images together

# %%
import matplotlib.pyplot as plt
def visualize(**images):
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()

# %% [markdown]
# #### Importing Dataset

# %%
dataset_path = r'/content/drive/MyDrive/test_vegetation_model'
dataset = Dataset(dataset_path, n_classes=2, augmentation=aug())

# %% [markdown]
# ### Visualization of Data

# %%
image, mask = dataset[0]
visualize(
    image=image,
    combined_mask = (mask[..., 1].squeeze())*0.4+(mask[..., 0].squeeze())*0.6,
    coniferous_mask = mask[..., 1].squeeze(),
    deciduous_mask = mask[..., 0].squeeze()
)

# %% [markdown]
# ### With Augmentation:

# %%
image, mask = dataset[(len(dataset)//2)]
visualize(
    image=image,
    combined_mask = (mask[..., 1].squeeze())*0.4+(mask[..., 0].squeeze())*0.6,
    coniferous_mask = mask[..., 1].squeeze(),
    deciduous_mask = mask[..., 0].squeeze()
)

# %% [markdown]
# ### Training and Validation Dataset
# Training Data: 85%
#
# Validation/Testing Data: 15%

# %%
from sklearn.model_selection import train_test_split

dataset_indexes=list(range(0,len(dataset)))
train_dataset, test_dataset = train_test_split(dataset_indexes, test_size = 0.15, random_state = 42)

# %% [markdown]
# #### Importing segmentation_models library for Model creation

# %%
# !pip install tensorflow==2.8.0 keras==2.8.0 segmentation-models==1.0.1
# Out:
# Requirement already satisfied: tensorflow==2.8.0 in /usr/local/lib/python3.10/dist-packages (2.8.0)
# Requirement already satisfied: keras==2.8.0 in /usr/local/lib/python3.10/dist-packages (2.8.0)
# Requirement already satisfied: segmentation-models==1.0.1 in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (24.3.25)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (3.12.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (3.4.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (3.19.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.17.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (2.8.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (2.8.0.dev2021122109)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.68.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from segmentation-models==1.0.1) (1.0.8)
# Requirement already satisfied: image-classifiers==1.0.0 in /usr/local/lib/python3.10/dist-packages (from segmentation-models==1.0.1) (1.0.0)
# Requirement already satisfied: efficientnet==1.0.0 in /usr/local/lib/python3.10/dist-packages (from segmentation-models==1.0.1) (1.0.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation-models==1.0.1) (0.24.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.8.0) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.0.2)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (11.0.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models==1.0.1) (0.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.2.2)

# %%
import os
os.environ['SM_FRAMEWORK'] = 'tf.keras'

import segmentation_models as sm
# Out:
# Segmentation Models: using `tf.keras` framework.

# %% [markdown]
# #### Defining loss and performance metrics

# %%
dice_loss = sm.losses.JaccardLoss()
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]

# %%
BACKBONE = 'efficientnetb3'
LR = 0.001
n_classes = 3  # 3 classes: background (0), and two object classes (100, 200)
activation = 'softmax'
sm.set_framework('tf.keras')

model = sm.Unet(BACKBONE, classes=n_classes, activation=activation)
opt = tf.keras.optimizers.Adam(LR)

# Use sparse categorical crossentropy for integer-encoded masks
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=metrics)

# %%
train_dataloader = Dataloder(train_dataset,dataset, batch_size=1)
test_dataloader = Dataloder(test_dataset,dataset, batch_size=1)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  stem_conv (Conv2D)             (None, None, None,   1080        ['input_2[0][0]']
#                                 40)
#
#  stem_bn (BatchNormalization)   (None, None, None,   160         ['stem_conv[0][0]']
#                                 40)
#
#  stem_activation (Activation)   (None, None, None,   0           ['stem_bn[0][0]']
#                                 40)
#
#  block1a_dwconv (DepthwiseConv2  (None, None, None,   360        ['stem_activation[0][0]']
#  D)                             40)
#
#  block1a_bn (BatchNormalization  (None, None, None,   160        ['block1a_dwconv[0][0]']
#  )                              40)
#
#  block1a_activation (Activation  (None, None, None,   0          ['block1a_bn[0][0]']
#  )                              40)
#
#  block1a_se_squeeze (GlobalAver  (None, 40)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 40)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 10)     410         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 40)     440         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, None, None,   0           ['block1a_activation[0][0]',
#                                 40)                               'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, None, None,   960         ['block1a_se_excite[0][0]']
#                                 24)
#
#  block1a_project_bn (BatchNorma  (None, None, None,   96         ['block1a_project_conv[0][0]']
#  lization)                      24)
#
#  block1b_dwconv (DepthwiseConv2  (None, None, None,   216        ['block1a_project_bn[0][0]']
#  D)                             24)
#
#  block1b_bn (BatchNormalization  (None, None, None,   96         ['block1b_dwconv[0][0]']
#  )                              24)
#
#  block1b_activation (Activation  (None, None, None,   0          ['block1b_bn[0][0]']
#  )                              24)
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, None, None,   0           ['block1b_activation[0][0]',
#                                 24)                               'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, None, None,   576         ['block1b_se_excite[0][0]']
#                                 24)
#
#  block1b_project_bn (BatchNorma  (None, None, None,   96         ['block1b_project_conv[0][0]']
#  lization)                      24)
#
#  block1b_drop (FixedDropout)    (None, None, None,   0           ['block1b_project_bn[0][0]']
#                                 24)
#
#  block1b_add (Add)              (None, None, None,   0           ['block1b_drop[0][0]',
#                                 24)                               'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, None, None,   3456        ['block1b_add[0][0]']
#                                 144)
#
#  block2a_expand_bn (BatchNormal  (None, None, None,   576        ['block2a_expand_conv[0][0]']
#  ization)                       144)
#
#  block2a_expand_activation (Act  (None, None, None,   0          ['block2a_expand_bn[0][0]']
#  ivation)                       144)
#
#  block2a_dwconv (DepthwiseConv2  (None, None, None,   1296       ['block2a_expand_activation[0][0]
#  D)                             144)                             ']
#
#  block2a_bn (BatchNormalization  (None, None, None,   576        ['block2a_dwconv[0][0]']
#  )                              144)
#
#  block2a_activation (Activation  (None, None, None,   0          ['block2a_bn[0][0]']
#  )                              144)
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, None, None,   0           ['block2a_activation[0][0]',
#                                 144)                              'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, None, None,   4608        ['block2a_se_excite[0][0]']
#                                 32)
#
#  block2a_project_bn (BatchNorma  (None, None, None,   128        ['block2a_project_conv[0][0]']
#  lization)                      32)
#
#  block2b_expand_conv (Conv2D)   (None, None, None,   6144        ['block2a_project_bn[0][0]']
#                                 192)
#
#  block2b_expand_bn (BatchNormal  (None, None, None,   768        ['block2b_expand_conv[0][0]']
#  ization)                       192)
#
#  block2b_expand_activation (Act  (None, None, None,   0          ['block2b_expand_bn[0][0]']
#  ivation)                       192)
#
#  block2b_dwconv (DepthwiseConv2  (None, None, None,   1728       ['block2b_expand_activation[0][0]
#  D)                             192)                             ']
#
#  block2b_bn (BatchNormalization  (None, None, None,   768        ['block2b_dwconv[0][0]']
#  )                              192)
#
#  block2b_activation (Activation  (None, None, None,   0          ['block2b_bn[0][0]']
#  )                              192)
#
#  block2b_se_squeeze (GlobalAver  (None, 192)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, None, None,   0           ['block2b_activation[0][0]',
#                                 192)                              'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, None, None,   6144        ['block2b_se_excite[0][0]']
#                                 32)
#
#  block2b_project_bn (BatchNorma  (None, None, None,   128        ['block2b_project_conv[0][0]']
#  lization)                      32)
#
#  block2b_drop (FixedDropout)    (None, None, None,   0           ['block2b_project_bn[0][0]']
#                                 32)
#
#  block2b_add (Add)              (None, None, None,   0           ['block2b_drop[0][0]',
#                                 32)                               'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, None, None,   6144        ['block2b_add[0][0]']
#                                 192)
#
#  block2c_expand_bn (BatchNormal  (None, None, None,   768        ['block2c_expand_conv[0][0]']
#  ization)                       192)
#
#  block2c_expand_activation (Act  (None, None, None,   0          ['block2c_expand_bn[0][0]']
#  ivation)                       192)
#
#  block2c_dwconv (DepthwiseConv2  (None, None, None,   1728       ['block2c_expand_activation[0][0]
#  D)                             192)                             ']
#
#  block2c_bn (BatchNormalization  (None, None, None,   768        ['block2c_dwconv[0][0]']
#  )                              192)
#
#  block2c_activation (Activation  (None, None, None,   0          ['block2c_bn[0][0]']
#  )                              192)
#
#  block2c_se_squeeze (GlobalAver  (None, 192)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, None, None,   0           ['block2c_activation[0][0]',
#                                 192)                              'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, None, None,   6144        ['block2c_se_excite[0][0]']
#                                 32)
#
#  block2c_project_bn (BatchNorma  (None, None, None,   128        ['block2c_project_conv[0][0]']
#  lization)                      32)
#
#  block2c_drop (FixedDropout)    (None, None, None,   0           ['block2c_project_bn[0][0]']
#                                 32)
#
#  block2c_add (Add)              (None, None, None,   0           ['block2c_drop[0][0]',
#                                 32)                               'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, None, None,   6144        ['block2c_add[0][0]']
#                                 192)
#
#  block3a_expand_bn (BatchNormal  (None, None, None,   768        ['block3a_expand_conv[0][0]']
#  ization)                       192)
#
#  block3a_expand_activation (Act  (None, None, None,   0          ['block3a_expand_bn[0][0]']
#  ivation)                       192)
#
#  block3a_dwconv (DepthwiseConv2  (None, None, None,   4800       ['block3a_expand_activation[0][0]
#  D)                             192)                             ']
#
#  block3a_bn (BatchNormalization  (None, None, None,   768        ['block3a_dwconv[0][0]']
#  )                              192)
#
#  block3a_activation (Activation  (None, None, None,   0          ['block3a_bn[0][0]']
#  )                              192)
#
#  block3a_se_squeeze (GlobalAver  (None, 192)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, None, None,   0           ['block3a_activation[0][0]',
#                                 192)                              'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, None, None,   9216        ['block3a_se_excite[0][0]']
#                                 48)
#
#  block3a_project_bn (BatchNorma  (None, None, None,   192        ['block3a_project_conv[0][0]']
#  lization)                      48)
#
#  block3b_expand_conv (Conv2D)   (None, None, None,   13824       ['block3a_project_bn[0][0]']
#                                 288)
#
#  block3b_expand_bn (BatchNormal  (None, None, None,   1152       ['block3b_expand_conv[0][0]']
#  ization)                       288)
#
#  block3b_expand_activation (Act  (None, None, None,   0          ['block3b_expand_bn[0][0]']
#  ivation)                       288)
#
#  block3b_dwconv (DepthwiseConv2  (None, None, None,   7200       ['block3b_expand_activation[0][0]
#  D)                             288)                             ']
#
#  block3b_bn (BatchNormalization  (None, None, None,   1152       ['block3b_dwconv[0][0]']
#  )                              288)
#
#  block3b_activation (Activation  (None, None, None,   0          ['block3b_bn[0][0]']
#  )                              288)
#
#  block3b_se_squeeze (GlobalAver  (None, 288)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, None, None,   0           ['block3b_activation[0][0]',
#                                 288)                              'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, None, None,   13824       ['block3b_se_excite[0][0]']
#                                 48)
#
#  block3b_project_bn (BatchNorma  (None, None, None,   192        ['block3b_project_conv[0][0]']
#  lization)                      48)
#
#  block3b_drop (FixedDropout)    (None, None, None,   0           ['block3b_project_bn[0][0]']
#                                 48)
#
#  block3b_add (Add)              (None, None, None,   0           ['block3b_drop[0][0]',
#                                 48)                               'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, None, None,   13824       ['block3b_add[0][0]']
#                                 288)
#
#  block3c_expand_bn (BatchNormal  (None, None, None,   1152       ['block3c_expand_conv[0][0]']
#  ization)                       288)
#
#  block3c_expand_activation (Act  (None, None, None,   0          ['block3c_expand_bn[0][0]']
#  ivation)                       288)
#
#  block3c_dwconv (DepthwiseConv2  (None, None, None,   7200       ['block3c_expand_activation[0][0]
#  D)                             288)                             ']
#
#  block3c_bn (BatchNormalization  (None, None, None,   1152       ['block3c_dwconv[0][0]']
#  )                              288)
#
#  block3c_activation (Activation  (None, None, None,   0          ['block3c_bn[0][0]']
#  )                              288)
#
#  block3c_se_squeeze (GlobalAver  (None, 288)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, None, None,   0           ['block3c_activation[0][0]',
#                                 288)                              'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, None, None,   13824       ['block3c_se_excite[0][0]']
#                                 48)
#
#  block3c_project_bn (BatchNorma  (None, None, None,   192        ['block3c_project_conv[0][0]']
#  lization)                      48)
#
#  block3c_drop (FixedDropout)    (None, None, None,   0           ['block3c_project_bn[0][0]']
#                                 48)
#
#  block3c_add (Add)              (None, None, None,   0           ['block3c_drop[0][0]',
#                                 48)                               'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, None, None,   13824       ['block3c_add[0][0]']
#                                 288)
#
#  block4a_expand_bn (BatchNormal  (None, None, None,   1152       ['block4a_expand_conv[0][0]']
#  ization)                       288)
#
#  block4a_expand_activation (Act  (None, None, None,   0          ['block4a_expand_bn[0][0]']
#  ivation)                       288)
#
#  block4a_dwconv (DepthwiseConv2  (None, None, None,   2592       ['block4a_expand_activation[0][0]
#  D)                             288)                             ']
#
#  block4a_bn (BatchNormalization  (None, None, None,   1152       ['block4a_dwconv[0][0]']
#  )                              288)
#
#  block4a_activation (Activation  (None, None, None,   0          ['block4a_bn[0][0]']
#  )                              288)
#
#  block4a_se_squeeze (GlobalAver  (None, 288)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, None, None,   0           ['block4a_activation[0][0]',
#                                 288)                              'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, None, None,   27648       ['block4a_se_excite[0][0]']
#                                 96)
#
#  block4a_project_bn (BatchNorma  (None, None, None,   384        ['block4a_project_conv[0][0]']
#  lization)                      96)
#
#  block4b_expand_conv (Conv2D)   (None, None, None,   55296       ['block4a_project_bn[0][0]']
#                                 576)
#
#  block4b_expand_bn (BatchNormal  (None, None, None,   2304       ['block4b_expand_conv[0][0]']
#  ization)                       576)
#
#  block4b_expand_activation (Act  (None, None, None,   0          ['block4b_expand_bn[0][0]']
#  ivation)                       576)
#
#  block4b_dwconv (DepthwiseConv2  (None, None, None,   5184       ['block4b_expand_activation[0][0]
#  D)                             576)                             ']
#
#  block4b_bn (BatchNormalization  (None, None, None,   2304       ['block4b_dwconv[0][0]']
#  )                              576)
#
#  block4b_activation (Activation  (None, None, None,   0          ['block4b_bn[0][0]']
#  )                              576)
#
#  block4b_se_squeeze (GlobalAver  (None, 576)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, None, None,   0           ['block4b_activation[0][0]',
#                                 576)                              'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, None, None,   55296       ['block4b_se_excite[0][0]']
#                                 96)
#
#  block4b_project_bn (BatchNorma  (None, None, None,   384        ['block4b_project_conv[0][0]']
#  lization)                      96)
#
#  block4b_drop (FixedDropout)    (None, None, None,   0           ['block4b_project_bn[0][0]']
#                                 96)
#
#  block4b_add (Add)              (None, None, None,   0           ['block4b_drop[0][0]',
#                                 96)                               'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, None, None,   55296       ['block4b_add[0][0]']
#                                 576)
#
#  block4c_expand_bn (BatchNormal  (None, None, None,   2304       ['block4c_expand_conv[0][0]']
#  ization)                       576)
#
#  block4c_expand_activation (Act  (None, None, None,   0          ['block4c_expand_bn[0][0]']
#  ivation)                       576)
#
#  block4c_dwconv (DepthwiseConv2  (None, None, None,   5184       ['block4c_expand_activation[0][0]
#  D)                             576)                             ']
#
#  block4c_bn (BatchNormalization  (None, None, None,   2304       ['block4c_dwconv[0][0]']
#  )                              576)
#
#  block4c_activation (Activation  (None, None, None,   0          ['block4c_bn[0][0]']
#  )                              576)
#
#  block4c_se_squeeze (GlobalAver  (None, 576)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, None, None,   0           ['block4c_activation[0][0]',
#                                 576)                              'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, None, None,   55296       ['block4c_se_excite[0][0]']
#                                 96)
#
#  block4c_project_bn (BatchNorma  (None, None, None,   384        ['block4c_project_conv[0][0]']
#  lization)                      96)
#
#  block4c_drop (FixedDropout)    (None, None, None,   0           ['block4c_project_bn[0][0]']
#                                 96)
#
#  block4c_add (Add)              (None, None, None,   0           ['block4c_drop[0][0]',
#                                 96)                               'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, None, None,   55296       ['block4c_add[0][0]']
#                                 576)
#
#  block4d_expand_bn (BatchNormal  (None, None, None,   2304       ['block4d_expand_conv[0][0]']
#  ization)                       576)
#
#  block4d_expand_activation (Act  (None, None, None,   0          ['block4d_expand_bn[0][0]']
#  ivation)                       576)
#
#  block4d_dwconv (DepthwiseConv2  (None, None, None,   5184       ['block4d_expand_activation[0][0]
#  D)                             576)                             ']
#
#  block4d_bn (BatchNormalization  (None, None, None,   2304       ['block4d_dwconv[0][0]']
#  )                              576)
#
#  block4d_activation (Activation  (None, None, None,   0          ['block4d_bn[0][0]']
#  )                              576)
#
#  block4d_se_squeeze (GlobalAver  (None, 576)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, None, None,   0           ['block4d_activation[0][0]',
#                                 576)                              'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, None, None,   55296       ['block4d_se_excite[0][0]']
#                                 96)
#
#  block4d_project_bn (BatchNorma  (None, None, None,   384        ['block4d_project_conv[0][0]']
#  lization)                      96)
#
#  block4d_drop (FixedDropout)    (None, None, None,   0           ['block4d_project_bn[0][0]']
#                                 96)
#
#  block4d_add (Add)              (None, None, None,   0           ['block4d_drop[0][0]',
#                                 96)                               'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, None, None,   55296       ['block4d_add[0][0]']
#                                 576)
#
#  block4e_expand_bn (BatchNormal  (None, None, None,   2304       ['block4e_expand_conv[0][0]']
#  ization)                       576)
#
#  block4e_expand_activation (Act  (None, None, None,   0          ['block4e_expand_bn[0][0]']
# ...
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 2304)   223488      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, None, None,   0           ['block7b_activation[0][0]',
#                                 2304)                             'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, None, None,   884736      ['block7b_se_excite[0][0]']
#                                 384)
#
#  block7b_project_bn (BatchNorma  (None, None, None,   1536       ['block7b_project_conv[0][0]']
#  lization)                      384)
#
#  block7b_drop (FixedDropout)    (None, None, None,   0           ['block7b_project_bn[0][0]']
#                                 384)
#
#  block7b_add (Add)              (None, None, None,   0           ['block7b_drop[0][0]',
#                                 384)                              'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)              (None, None, None,   589824      ['block7b_add[0][0]']
#                                 1536)
#
#  top_bn (BatchNormalization)    (None, None, None,   6144        ['top_conv[0][0]']
#                                 1536)
#
#  top_activation (Activation)    (None, None, None,   0           ['top_bn[0][0]']
#                                 1536)
#
#  decoder_stage0_upsampling (UpS  (None, None, None,   0          ['top_activation[0][0]']
#  ampling2D)                     1536)
#
#  decoder_stage0_concat (Concate  (None, None, None,   0          ['decoder_stage0_upsampling[0][0]
#  nate)                          2352)                            ',
#                                                                   'block6a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage0a_conv (Conv2D)  (None, None, None,   5419008     ['decoder_stage0_concat[0][0]']
#                                 256)
#
#  decoder_stage0a_bn (BatchNorma  (None, None, None,   1024       ['decoder_stage0a_conv[0][0]']
#  lization)                      256)
#
#  decoder_stage0a_relu (Activati  (None, None, None,   0          ['decoder_stage0a_bn[0][0]']
#  on)                            256)
#
#  decoder_stage0b_conv (Conv2D)  (None, None, None,   589824      ['decoder_stage0a_relu[0][0]']
#                                 256)
#
#  decoder_stage0b_bn (BatchNorma  (None, None, None,   1024       ['decoder_stage0b_conv[0][0]']
#  lization)                      256)
#
#  decoder_stage0b_relu (Activati  (None, None, None,   0          ['decoder_stage0b_bn[0][0]']
#  on)                            256)
#
#  decoder_stage1_upsampling (UpS  (None, None, None,   0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)                     256)
#
#  decoder_stage1_concat (Concate  (None, None, None,   0          ['decoder_stage1_upsampling[0][0]
#  nate)                          544)                             ',
#                                                                   'block4a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage1a_conv (Conv2D)  (None, None, None,   626688      ['decoder_stage1_concat[0][0]']
#                                 128)
#
#  decoder_stage1a_bn (BatchNorma  (None, None, None,   512        ['decoder_stage1a_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1a_relu (Activati  (None, None, None,   0          ['decoder_stage1a_bn[0][0]']
#  on)                            128)
#
#  decoder_stage1b_conv (Conv2D)  (None, None, None,   147456      ['decoder_stage1a_relu[0][0]']
#                                 128)
#
#  decoder_stage1b_bn (BatchNorma  (None, None, None,   512        ['decoder_stage1b_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1b_relu (Activati  (None, None, None,   0          ['decoder_stage1b_bn[0][0]']
#  on)                            128)
#
#  decoder_stage2_upsampling (UpS  (None, None, None,   0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)                     128)
#
#  decoder_stage2_concat (Concate  (None, None, None,   0          ['decoder_stage2_upsampling[0][0]
#  nate)                          320)                             ',
#                                                                   'block3a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage2a_conv (Conv2D)  (None, None, None,   184320      ['decoder_stage2_concat[0][0]']
#                                 64)
#
#  decoder_stage2a_bn (BatchNorma  (None, None, None,   256        ['decoder_stage2a_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2a_relu (Activati  (None, None, None,   0          ['decoder_stage2a_bn[0][0]']
#  on)                            64)
#
#  decoder_stage2b_conv (Conv2D)  (None, None, None,   36864       ['decoder_stage2a_relu[0][0]']
#                                 64)
#
#  decoder_stage2b_bn (BatchNorma  (None, None, None,   256        ['decoder_stage2b_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2b_relu (Activati  (None, None, None,   0          ['decoder_stage2b_bn[0][0]']
#  on)                            64)
#
#  decoder_stage3_upsampling (UpS  (None, None, None,   0          ['decoder_stage2b_relu[0][0]']
#  ampling2D)                     64)
#
#  decoder_stage3_concat (Concate  (None, None, None,   0          ['decoder_stage3_upsampling[0][0]
#  nate)                          208)                             ',
#                                                                   'block2a_expand_activation[0][0]
#                                                                  ']
#
#  decoder_stage3a_conv (Conv2D)  (None, None, None,   59904       ['decoder_stage3_concat[0][0]']
#                                 32)
#
#  decoder_stage3a_bn (BatchNorma  (None, None, None,   128        ['decoder_stage3a_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3a_relu (Activati  (None, None, None,   0          ['decoder_stage3a_bn[0][0]']
#  on)                            32)
#
#  decoder_stage3b_conv (Conv2D)  (None, None, None,   9216        ['decoder_stage3a_relu[0][0]']
#                                 32)
#
#  decoder_stage3b_bn (BatchNorma  (None, None, None,   128        ['decoder_stage3b_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3b_relu (Activati  (None, None, None,   0          ['decoder_stage3b_bn[0][0]']
#  on)                            32)
#
#  decoder_stage4_upsampling (UpS  (None, None, None,   0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     32)
#
#  decoder_stage4a_conv (Conv2D)  (None, None, None,   4608        ['decoder_stage4_upsampling[0][0]
#                                 16)                              ']
#
#  decoder_stage4a_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4a_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4a_relu (Activati  (None, None, None,   0          ['decoder_stage4a_bn[0][0]']
#  on)                            16)
#
#  decoder_stage4b_conv (Conv2D)  (None, None, None,   2304        ['decoder_stage4a_relu[0][0]']
#                                 16)
#
#  decoder_stage4b_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4b_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4b_relu (Activati  (None, None, None,   0          ['decoder_stage4b_bn[0][0]']
#  on)                            16)
#
#  final_conv (Conv2D)            (None, None, None,   435         ['decoder_stage4b_relu[0][0]']
#                                 3)
#
#  softmax (Activation)           (None, None, None,   0           ['final_conv[0][0]']
#                                 3)
#
# ==================================================================================================
# Total params: 17,868,123
# Trainable params: 17,778,843
# Non-trainable params: 89,280
# __________________________________________________________________________________________________

# %% [markdown]
# ### Model Training

# %%
# Initialize dataset
dataset_path = r'C:/Users/Medhansh Jindal/OneDrive/Desktop/New_Sample'

# Check dataloader sizes
print(f"Train dataloader size: {len(train_dataloader)}")
print(f"Test dataloader size: {len(test_dataloader)}")


# Train model
steps_per_epoch = max(1, len(train_dataloader))
validation_steps = max(1, len(test_dataloader))

history = model.fit(
    train_dataloader,
    steps_per_epoch=len(train_dataloader),
    epochs=40,
    validation_data=test_dataloader,
    validation_steps=len(test_dataloader),

    callbacks=[
        keras.callbacks.ReduceLROnPlateau(),
        tf.keras.callbacks.EarlyStopping('val_loss', patience=5),
    ]
)
# Out:
# Train dataloader size: 13
# Test dataloader size: 3
# Epoch 1/40
# 13/13 [==============================] - 42s 2s/step - loss: 0.8356 - iou_score: 0.3673 - f1-score: 0.4945 - val_loss: 3.8879 - val_iou_score: 0.1789 - val_f1-score: 0.2582 - lr: 0.0010
# Epoch 2/40
# 13/13 [==============================] - 26s 2s/step - loss: 0.5253 - iou_score: 0.6444 - f1-score: 0.7627 - val_loss: 16.6259 - val_iou_score: 0.3221 - val_f1-score: 0.4530 - lr: 0.0010
# Epoch 3/40
# 13/13 [==============================] - 23s 2s/step - loss: 0.4408 - iou_score: 0.7085 - f1-score: 0.8131 - val_loss: 7.6620 - val_iou_score: 0.4298 - val_f1-score: 0.5611 - lr: 0.0010
# Epoch 4/40
# 13/13 [==============================] - 25s 2s/step - loss: 0.4515 - iou_score: 0.7140 - f1-score: 0.8159 - val_loss: 6.1080 - val_iou_score: 0.4660 - val_f1-score: 0.5943 - lr: 0.0010
# Epoch 5/40
# 13/13 [==============================] - 25s 2s/step - loss: 0.4205 - iou_score: 0.7322 - f1-score: 0.8276 - val_loss: 2.5971 - val_iou_score: 0.4638 - val_f1-score: 0.5920 - lr: 0.0010
# Epoch 6/40
# 13/13 [==============================] - 23s 2s/step - loss: 0.3991 - iou_score: 0.7418 - f1-score: 0.8352 - val_loss: 1.4113 - val_iou_score: 0.5522 - val_f1-score: 0.6596 - lr: 0.0010
# Epoch 7/40
# 13/13 [==============================] - 26s 2s/step - loss: 0.3865 - iou_score: 0.7425 - f1-score: 0.8350 - val_loss: 0.9806 - val_iou_score: 0.5437 - val_f1-score: 0.6461 - lr: 0.0010
# Epoch 8/40
# 13/13 [==============================] - 23s 2s/step - loss: 0.3924 - iou_score: 0.7367 - f1-score: 0.8309 - val_loss: 0.9714 - val_iou_score: 0.5806 - val_f1-score: 0.6790 - lr: 0.0010
# Epoch 9/40
# 13/13 [==============================] - 23s 2s/step - loss: 0.4338 - iou_score: 0.7397 - f1-score: 0.8331 - val_loss: 1.0533 - val_iou_score: 0.5365 - val_f1-score: 0.6499 - lr: 0.0010
# Epoch 10/40
# 13/13 [==============================] - 23s 2s/step - loss: 0.3715 - iou_score: 0.7610 - f1-score: 0.8473 - val_loss: 0.9467 - val_iou_score: 0.5399 - val_f1-score: 0.6517 - lr: 0.0010
# Epoch 11/40
# 13/13 [==============================] - 24s 2s/step - loss: 0.3793 - iou_score: 0.7469 - f1-score: 0.8369 - val_loss: 0.8719 - val_iou_score: 0.5642 - val_f1-score: 0.6690 - lr: 0.0010
# Epoch 12/40
# 13/13 [==============================] - 22s 2s/step - loss: 0.3564 - iou_score: 0.7680 - f1-score: 0.8505 - val_loss: 0.8629 - val_iou_score: 0.5649 - val_f1-score: 0.6688 - lr: 0.0010
# Epoch 13/40
# 13/13 [==============================] - 23s 2s/step - loss: 0.4076 - iou_score: 0.7745 - f1-score: 0.8527 - val_loss: 0.7929 - val_iou_score: 0.5695 - val_f1-score: 0.6737 - lr: 0.0010
# Epoch 14/40
# 13/13 [==============================] - 23s 2s/step - loss: 0.3639 - iou_score: 0.7795 - f1-score: 0.8579 - val_loss: 0.8544 - val_iou_score: 0.5405 - val_f1-score: 0.6543 - lr: 0.0010
# Epoch 15/40
# 13/13 [==============================] - 23s 2s/step - loss: 0.3476 - iou_score: 0.7673 - f1-score: 0.8499 - val_loss: 0.7559 - val_iou_score: 0.5918 - val_f1-score: 0.6862 - lr: 0.0010
# Epoch 16/40
# 13/13 [==============================] - 22s 2s/step - loss: 0.3517 - iou_score: 0.7818 - f1-score: 0.8588 - val_loss: 0.7410 - val_iou_score: 0.5999 - val_f1-score: 0.6913 - lr: 0.0010
# Epoch 17/40
# 13/13 [==============================] - 26s 2s/step - loss: 0.3241 - iou_score: 0.7804 - f1-score: 0.8597 - val_loss: 0.7424 - val_iou_score: 0.5872 - val_f1-score: 0.6826 - lr: 0.0010
# Epoch 18/40
# 13/13 [==============================] - 23s 2s/step - loss: 0.3146 - iou_score: 0.7835 - f1-score: 0.8632 - val_loss: 0.7569 - val_iou_score: 0.5833 - val_f1-score: 0.6832 - lr: 0.0010
# Epoch 19/40
# 13/13 [==============================] - 24s 2s/step - loss: 0.3089 - iou_score: 0.7850 - f1-score: 0.8663 - val_loss: 0.7814 - val_iou_score: 0.5605 - val_f1-score: 0.6697 - lr: 0.0010
# Epoch 20/40
# 13/13 [==============================] - 22s 2s/step - loss: 0.3451 - iou_score: 0.7777 - f1-score: 0.8562 - val_loss: 0.7259 - val_iou_score: 0.5511 - val_f1-score: 0.6612 - lr: 0.0010
# Epoch 21/40
# 13/13 [==============================] - 24s 2s/step - loss: 0.3031 - iou_score: 0.7992 - f1-score: 0.8750 - val_loss: 0.7802 - val_iou_score: 0.5632 - val_f1-score: 0.6713 - lr: 0.0010
# Epoch 22/40
# 13/13 [==============================] - 22s 2s/step - loss: 0.3122 - iou_score: 0.7940 - f1-score: 0.8672 - val_loss: 0.7561 - val_iou_score: 0.5887 - val_f1-score: 0.6866 - lr: 0.0010
# Epoch 23/40
# 13/13 [==============================] - 24s 2s/step - loss: 0.3365 - iou_score: 0.7814 - f1-score: 0.8595 - val_loss: 0.7231 - val_iou_score: 0.5687 - val_f1-score: 0.6752 - lr: 0.0010
# Epoch 24/40
# 13/13 [==============================] - 23s 2s/step - loss: 0.3098 - iou_score: 0.7979 - f1-score: 0.8726 - val_loss: 0.6965 - val_iou_score: 0.6001 - val_f1-score: 0.6988 - lr: 0.0010
# Epoch 25/40
# 13/13 [==============================] - 23s 2s/step - loss: 0.2838 - iou_score: 0.8020 - f1-score: 0.8771 - val_loss: 0.7586 - val_iou_score: 0.6071 - val_f1-score: 0.7039 - lr: 0.0010
# Epoch 26/40
# 13/13 [==============================] - 23s 2s/step - loss: 0.3038 - iou_score: 0.7985 - f1-score: 0.8723 - val_loss: 0.7324 - val_iou_score: 0.5945 - val_f1-score: 0.6956 - lr: 0.0010
# Epoch 27/40
# 13/13 [==============================] - 24s 2s/step - loss: 0.4371 - iou_score: 0.7608 - f1-score: 0.8459 - val_loss: 0.6832 - val_iou_score: 0.5863 - val_f1-score: 0.7017 - lr: 0.0010
# Epoch 28/40
# 13/13 [==============================] - 24s 2s/step - loss: 0.3519 - iou_score: 0.7712 - f1-score: 0.8566 - val_loss: 0.6855 - val_iou_score: 0.6187 - val_f1-score: 0.7154 - lr: 0.0010
# Epoch 29/40
# 13/13 [==============================] - 24s 2s/step - loss: 0.3520 - iou_score: 0.7713 - f1-score: 0.8557 - val_loss: 0.6984 - val_iou_score: 0.6165 - val_f1-score: 0.7174 - lr: 0.0010
# Epoch 30/40
# 13/13 [==============================] - 24s 2s/step - loss: 0.3339 - iou_score: 0.7508 - f1-score: 0.8388 - val_loss: 0.6827 - val_iou_score: 0.6160 - val_f1-score: 0.7205 - lr: 0.0010
# Epoch 31/40
# 13/13 [==============================] - 22s 2s/step - loss: 0.3273 - iou_score: 0.7786 - f1-score: 0.8622 - val_loss: 0.7369 - val_iou_score: 0.5703 - val_f1-score: 0.6946 - lr: 0.0010
# Epoch 32/40
# 13/13 [==============================] - 24s 2s/step - loss: 0.2996 - iou_score: 0.7780 - f1-score: 0.8627 - val_loss: 0.8750 - val_iou_score: 0.5188 - val_f1-score: 0.6347 - lr: 0.0010
# Epoch 33/40
# 13/13 [==============================] - 22s 2s/step - loss: 0.3023 - iou_score: 0.7990 - f1-score: 0.8728 - val_loss: 0.7790 - val_iou_score: 0.5528 - val_f1-score: 0.6732 - lr: 0.0010
# Epoch 34/40
# 13/13 [==============================] - 24s 2s/step - loss: 0.3171 - iou_score: 0.7834 - f1-score: 0.8650 - val_loss: 1.3087 - val_iou_score: 0.4339 - val_f1-score: 0.5499 - lr: 0.0010
# Epoch 35/40
# 13/13 [==============================] - 23s 2s/step - loss: 0.2940 - iou_score: 0.8132 - f1-score: 0.8860 - val_loss: 0.8424 - val_iou_score: 0.5136 - val_f1-score: 0.6413 - lr: 0.0010

# %%
# Convert DataLoader to an iterator and fetch the first batch
batch = next(iter(train_dataloader))
images, masks = batch  # Assuming the DataLoader returns (input, target)

# Check the shapes and data types
print("Image shape:", images.shape, "dtype:", images.dtype)
print("Mask shape:", masks.shape, "dtype:", masks.dtype)
# Out:
# Image shape: (1, 256, 256, 3) dtype: float32
# Mask shape: (1, 256, 256, 3) dtype: float32

# %%
batch = next(iter(train_dataloader))
print(type(batch))  # Check if it's a tuple
print(len(batch))   # Should be 2 (inputs and targets)
print("Image dtype:", batch[0].dtype, "Shape:", batch[0].shape)
print("Mask dtype:", batch[1].dtype, "Shape:", batch[1].shape)
# Out:
# <class 'tuple'>
# 2
# Image dtype: float32 Shape: (1, 256, 256, 3)
# Mask dtype: float32 Shape: (1, 256, 256, 3)

# %%
model.save('my_model.h5')

# %% [markdown]
# ### Evaluation

# %%
plt.figure(figsize=(10, 3))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10, 3))
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(test_dataloader)
# Out:
# 3/3 [==============================] - 1s 301ms/step - loss: 0.8424 - iou_score: 0.5136 - f1-score: 0.6413

# %%
print("Loss: ",scores[0])
print("iou :",scores[1])
print("f1-score :",scores[2])
# Out:
# Loss:  0.8423506617546082
# iou : 0.5135912895202637
# f1-score : 0.6412563920021057

# %%
test_pred =model.predict(test_dataloader)

# %% [markdown]
# ### True Mask

# %%
image,mask = test_dataloader[0]

img=image[0]
visualize(
    image=img,
    combined_mask = (mask[..., 1].squeeze())*0.4+(mask[..., 0].squeeze())*0.6,
    coniferous_mask = mask[..., 1].squeeze(),
    deciduous_mask = mask[..., 0].squeeze()
)

# %% [markdown]
# ### Predicted Mask

# %%
mask = test_pred[0]>0.5

visualize(
    image=img,
    combined_mask = (mask[..., 1].squeeze())*0.4+(mask[..., 0].squeeze())*0.6,
    coniferous_mask = mask[..., 1].squeeze(),
    deciduous_mask = mask[..., 0].squeeze()
)
